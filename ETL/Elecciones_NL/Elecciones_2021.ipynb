# %%
## Dependencies
import pandas as pd

# %%
ayuntamientos_2021 = pd.read_csv("data/CEENL-Ayuntamientos-2021.csv", encoding="latin-1", skiprows=5)
ayuntamientos_2021.head()
# Out:
#    190001B0100  190001B01004  19  NUEVO LEON  001     Abasolo  0001  0001.1  \
# 0  190001C0100  190001C01004  19  NUEVO LEON    1     Abasolo     1       1
# 1  190002B0100  190002B01004  19  NUEVO LEON    1     Abasolo     2       1
# 2  190002C0100  190002C01004  19  NUEVO LEON    1     Abasolo     2       1
# 3  190003B0100  190003B01004  19  NUEVO LEON    2  Agualeguas     3       1
# 4  190003C0100  190003C01004  19  NUEVO LEON    2  Agualeguas     3       1
#
#    B  00  ...   Por CME  1  D  Unnamed: 50  Unnamed: 51  09/06/2021 08:26:41  \
# 0  C   0  ...   Por CME  1  D          NaN          NaN  09/06/2021 09:45:25
# 1  B   0  ...   Por CME  1  D          NaN          NaN  09/06/2021 11:00:20
# 2  C   0  ...   Por CME  1  D          NaN          NaN  09/06/2021 11:58:10
# 3  B   0  ...   Por CME  1  D          NaN          NaN  09/06/2021 09:06:21
# 4  C   0  ...   Por CME  1  D          NaN          NaN  09/06/2021 09:07:11
#
#    Unnamed: 53  Unnamed: 54  Unnamed: 55  -
# ...

# %%
gubernatura_2021 = pd.read_csv("data/CEENL-Gubernatura-2021.csv", encoding="latin-1", skiprows=5)
gubernatura_2021.head()
# Out:
#    190001B0100  190001B01002  19  NUEVO LEON  001     Abasolo  020  \
# 0  190001C0100  190001C01002  19  NUEVO LEON    1     Abasolo   20
# 1  190002B0100  190002B01002  19  NUEVO LEON    1     Abasolo   20
# 2  190002C0100  190002C01002  19  NUEVO LEON    1     Abasolo   20
# 3  190003B0100  190003B01002  19  NUEVO LEON    2  Agualeguas   21
# 4  190003C0100  190003C01002  19  NUEVO LEON    2  Agualeguas   21
#
#    DISTRITO 20  0001  0001.1  ...   Por MAC  1.2  D  Unnamed: 50  Unnamed: 51  \
# 0  DISTRITO 20     1       1  ...   Por MAC    1  D          NaN          NaN
# 1  DISTRITO 20     2       1  ...   Por MAC    1  D          NaN          NaN
# 2  DISTRITO 20     2       1  ...   Por MAC    1  D          NaN          NaN
# 3  DISTRITO 21     3       1  ...   Por MAC    1  D          NaN          NaN
# 4  DISTRITO 21     3       1  ...   Por MAC    1  D          NaN          NaN
#
#    09/06/2021 09:33:55  Unnamed: 53  Unnamed: 54  Unnamed: 55  -
# ...
