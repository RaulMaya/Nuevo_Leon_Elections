# %% [markdown]
# ## Importing Dependencies

# %%
import pandas as pd
import requests
import json

# %%
first_path = "../../resources/data/Relacion ID-Municipios/ID-Municipios.csv"

# %%
id_municipality = pd.read_csv(first_path, encoding='latin-1')
id_municipality.head()
# Out:
#       ID    Municipio
# 0  19001      Abasolo
# 1  19002   Agualeguas
# 2  19003  Los Aldamas
# 3  19004      Allende
# 4  19005      Anáhuac

# %% [markdown]
# ## Storing API Links into variables

# %%
api_1 = "https://datamexico.org/api/data?State=19&Year=2018&cube=coneval_gini_mun&drilldowns=Municipality&measures=GINI&parents=true&sparse=false&locale=es"
api_2 = "https://datamexico.org/api/data?State=19&Year=2015&cube=inegi_population&drilldowns=Municipality&measures=Population&parents=false&sparse=false&locale=es"

# %%
nation_ids = []
nations = []
states_ids = []
states = []
municipality_ids = []
municipalities = []
ginis = []

c = 0
response = requests.get(api_1)
data = response.json()["data"]
data_length = len(data)
while c < data_length:
    nation_ids.append(data[c]['Nation ID'])
    nations.append(data[c]['Nation'])
    states_ids.append(data[c]['State ID'])
    states.append(data[c]['State'])
    municipality_ids.append(data[c]['Municipality ID'])
    municipalities.append(data[c]['Municipality'])
    ginis.append(data[c]['GINI'])
    c = c + 1

# %%
api_1_df = pd.DataFrame({"Nations ID":nation_ids,
                        "Nation":nations,
                        "State ID":states_ids,
                        "State":states,
                        "ID":municipality_ids,
                        "Municipality":municipalities,
                        "GINI":ginis})
api_1_df.head()
# Out:
#   Nations ID  Nation  State ID       State     ID Municipality      GINI
# 0        mex  México        19  Nuevo León  19001      Abasolo  0.396089
# 1        mex  México        19  Nuevo León  19002   Agualeguas  0.428212
# 2        mex  México        19  Nuevo León  19003  Los Aldamas  0.435469
# 3        mex  México        19  Nuevo León  19004      Allende  0.340558
# 4        mex  México        19  Nuevo León  19005      Anáhuac  0.383755

# %%
first_api = pd.merge(api_1_df, id_municipality, on = "ID", how = "inner")
first_api = first_api[["Nations ID", "Nation", "State ID","State", "ID", "Municipio", "GINI"]]
first_api
# Out:
#    Nations ID  Nation  State ID       State     ID                 Municipio  \
# 0         mex  México        19  Nuevo León  19001                   Abasolo
# 1         mex  México        19  Nuevo León  19002                Agualeguas
# 2         mex  México        19  Nuevo León  19003               Los Aldamas
# 3         mex  México        19  Nuevo León  19004                   Allende
# 4         mex  México        19  Nuevo León  19005                   Anáhuac
# 5         mex  México        19  Nuevo León  19006                   Apodaca
# 6         mex  México        19  Nuevo León  19007                 Aramberri
# 7         mex  México        19  Nuevo León  19008                Bustamante
# 8         mex  México        19  Nuevo León  19009         Cadereyta Jiménez
# 9         mex  México        19  Nuevo León  19010                 El Carmen
# 10        mex  México        19  Nuevo León  19011                  Cerralvo
# 11        mex  México        19  Nuevo León  19012         Ciénega de Flores
# 12        mex  México        19  Nuevo León  19013                     China
# 13        mex  México        19  Nuevo León  19014                Dr. Arroyo
# 14        mex  México        19  Nuevo León  19015                  Dr. Coss
# 15        mex  México        19  Nuevo León  19016              Dr. González
# 16        mex  México        19  Nuevo León  19017                   Galeana
# 17        mex  México        19  Nuevo León  19018                    García
# 18        mex  México        19  Nuevo León  19019    San Pedro Garza García
# 19        mex  México        19  Nuevo León  19020               Gral. Bravo
# 20        mex  México        19  Nuevo León  19021            Gral. Escobedo
# 21        mex  México        19  Nuevo León  19022               Gral. Terán
# 22        mex  México        19  Nuevo León  19023             Gral. Treviño
# 23        mex  México        19  Nuevo León  19024            Gral. Zaragoza
# 24        mex  México        19  Nuevo León  19025              Gral. Zuazua
# 25        mex  México        19  Nuevo León  19026                 Guadalupe
# 26        mex  México        19  Nuevo León  19027              Los Herreras
# 27        mex  México        19  Nuevo León  19028                  Higueras
# 28        mex  México        19  Nuevo León  19029               Hualahuises
# 29        mex  México        19  Nuevo León  19030                  Iturbide
# 30        mex  México        19  Nuevo León  19031                    Juárez
# 31        mex  México        19  Nuevo León  19032       Lampazos de Naranjo
# 32        mex  México        19  Nuevo León  19033                   Linares
# 33        mex  México        19  Nuevo León  19034                     Marín
# 34        mex  México        19  Nuevo León  19035            Melchor Ocampo
# 35        mex  México        19  Nuevo León  19036            Mier y Noriega
# 36        mex  México        19  Nuevo León  19037                      Mina
# 37        mex  México        19  Nuevo León  19038              Montemorelos
# 38        mex  México        19  Nuevo León  19039                 Monterrey
# 39        mex  México        19  Nuevo León  19040                     Parás
# 40        mex  México        19  Nuevo León  19041                 Pesquería
# 41        mex  México        19  Nuevo León  19042               Los Ramones
# 42        mex  México        19  Nuevo León  19043                   Rayones
# 43        mex  México        19  Nuevo León  19044           Sabinas Hidalgo
# 44        mex  México        19  Nuevo León  19045          Salinas Victoria
# 45        mex  México        19  Nuevo León  19046  San Nicolás de los Garza
# 46        mex  México        19  Nuevo León  19047                   Hidalgo
# 47        mex  México        19  Nuevo León  19048            Santa Catarina
# 48        mex  México        19  Nuevo León  19049                  Santiago
# 49        mex  México        19  Nuevo León  19050                Vallecillo
# 50        mex  México        19  Nuevo León  19051                Villaldama
#
#         GINI
# 0   0.396089
# 1   0.428212
# 2   0.435469
# 3   0.340558
# 4   0.383755
# 5   0.323524
# 6   0.463622
# 7   0.334266
# 8   0.368073
# 9   0.339524
# 10  0.355913
# 11  0.312557
# 12  0.361397
# 13  0.490310
# 14  0.413523
# 15  0.434400
# 16  0.473902
# 17  0.349600
# 18  0.363062
# 19  0.393138
# 20  0.371774
# 21  0.404092
# 22  0.413215
# 23  0.448942
# 24  0.306754
# 25  0.360587
# 26  0.439862
# 27  0.410315
# 28  0.382014
# 29  0.433981
# 30  0.336111
# 31  0.350161
# 32  0.380049
# 33  0.365430
# 34  0.428854
# 35  0.438683
# 36  0.367668
# 37  0.364047
# 38  0.387010
# 39  0.442122
# 40  0.346197
# 41  0.416500
# 42  0.435898
# 43  0.366129
# 44  0.357794
# 45  0.335964
# 46  0.350697
# 47  0.348132
# 48  0.349870
# 49  0.428824
# 50  0.390510

# %%
first_api.to_csv("outputs/dataframe_api_1.csv", index = True)

# %%
first_api.to_json("outputs/dataframe_api_1.js")

# %%
municipality_id_2 = []
municipality_2 = []
populations = []

c = 0
response = requests.get(api_2)
data_2 = response.json()["data"]
data_length = len(data_2)
while c < data_length:
    municipality_id_2.append(data[c]['Municipality ID'])
    municipality_2.append(data[c]['Municipality'])
    populations.append(data_2[c]["Population"])
    c = c + 1

# %%
api_2_df = pd.DataFrame({"ID":municipality_id_2,
                        "Municipality":municipality_2,
                        "Population":populations})

api_2_df.head()
# Out:
#       ID Municipality  Population
# 0  19001      Abasolo        2639
# 1  19002   Agualeguas        2439
# 2  19003  Los Aldamas        1292
# 3  19004      Allende       34353
# 4  19005      Anáhuac       18194

# %%
second_api = pd.merge(api_2_df, id_municipality, on = "ID", how = "inner")
second_api = second_api[["ID", "Municipio", "Population"]]
second_api
# Out:
#        ID                 Municipio  Population
# 0   19001                   Abasolo        2639
# 1   19002                Agualeguas        2439
# 2   19003               Los Aldamas        1292
# 3   19004                   Allende       34353
# 4   19005                   Anáhuac       18194
# 5   19006                   Apodaca      597207
# 6   19007                 Aramberri       16152
# 7   19008                Bustamante        3977
# 8   19009         Cadereyta Jiménez       95534
# 9   19010                 El Carmen       38306
# 10  19011                  Cerralvo        7757
# 11  19012         Ciénega de Flores       42715
# 12  19013                     China       10835
# 13  19014                Dr. Arroyo       34110
# 14  19015                  Dr. Coss        1632
# 15  19016              Dr. González        2861
# 16  19017                   Galeana       41130
# 17  19018                    García      247370
# 18  19019    San Pedro Garza García      123156
# 19  19020               Gral. Bravo        5479
# 20  19021            Gral. Escobedo      425148
# 21  19022               Gral. Terán       14795
# 22  19023             Gral. Treviño        1044
# 23  19024            Gral. Zaragoza        6011
# 24  19025              Gral. Zuazua       67294
# 25  19026                 Guadalupe      682880
# 26  19027              Los Herreras        1764
# 27  19028                  Higueras        1511
# 28  19029               Hualahuises        6921
# 29  19030                  Iturbide        3571
# 30  19031                    Juárez      333481
# 31  19032       Lampazos de Naranjo        5238
# 32  19033                   Linares       79853
# 33  19034                     Marín        5630
# 34  19035            Melchor Ocampo         955
# 35  19036            Mier y Noriega        6996
# 36  19037                      Mina        5326
# 37  19038              Montemorelos       60829
# 38  19039                 Monterrey     1109171
# 39  19040                     Parás         971
# 40  19041                 Pesquería       87168
# 41  19042               Los Ramones        4469
# 42  19043                   Rayones        2640
# 43  19044           Sabinas Hidalgo       35456
# 44  19045          Salinas Victoria       54192
# 45  19046  San Nicolás de los Garza      430143
# 46  19047                   Hidalgo       13836
# 47  19048            Santa Catarina      296954
# 48  19049                  Santiago       42407
# 49  19050                Vallecillo        1632
# 50  19051                Villaldama        4080

# %%
second_api.to_csv("outputs/dataframe_api_2.csv", index = True)

# %%
second_api.to_json("outputs/dataframe_api_2.js")

# %%
merged_apis = pd.merge(first_api, second_api, how = "inner")
merged_apis.head()
# Out:
#   Nations ID  Nation  State ID       State     ID    Municipio      GINI  \
# 0        mex  México        19  Nuevo León  19001      Abasolo  0.396089
# 1        mex  México        19  Nuevo León  19002   Agualeguas  0.428212
# 2        mex  México        19  Nuevo León  19003  Los Aldamas  0.435469
# 3        mex  México        19  Nuevo León  19004      Allende  0.340558
# 4        mex  México        19  Nuevo León  19005      Anáhuac  0.383755
#
#    Population
# 0        2639
# 1        2439
# 2        1292
# 3       34353
# 4       18194

# %%
merged_apis.to_csv("outputs/dataframe_merged_apis.csv", index = True)

# %%
merged_apis.to_json("outputs/dataframe_merged_apis.js")
