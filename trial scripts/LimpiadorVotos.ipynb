# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Alcaldes 2018

# %%
temp_content = pd.read_csv('NL_AYUN_2018.csv')

# %%
group = temp_content.groupby('MUNICIPIO')

# %%
NL_AYUN_2018 = group.sum()

# %%
NL_AYUN_2018.head()
# Out:
#             ID_ESTADO  ID_MUNICIPIO  SECCION  ID_CASILLA  EXT_CONTIGUA  \
# MUNICIPIO
# Abasolo            76             4        6           6           2.0
# Agualeguas        190            20       66          11           1.0
# Allende           874           184     1231          99          53.0
# Anahuac           513           135     1226          42          15.0
# Apodaca         13072          4128   812254        2836         886.0
#
#             UBICACION_CASILLA  TIPO_ACTA  TOTAL_BOLETAS_SOBRANTES  \
# MUNICIPIO
# Abasolo                     8         20                        0
# Agualeguas                 19         50                        0
# Allende                    60        230                        0
# Anahuac                    37        135                        0
# Apodaca                   727       3444                        0
#
#             TOTAL_PERSONAS_VOTARON  TOTAL_REP_PARTIDO_CI_VOTARON  ...  \
# ...

# %%
NL_AYUN_2018.drop(['ID_ESTADO','ID_MUNICIPIO','SECCION','ID_CASILLA','EXT_CONTIGUA','UBICACION_CASILLA','TIPO_ACTA','SHA','FECHA_HORA_ACOPIO','FECHA_HORA_VERIFICACION','ORIGEN','DIGITALIZACION'

], axis = 1, inplace= True)

# %%
NL_AYUN_2018.head()
# Out:
#             TOTAL_BOLETAS_SOBRANTES  TOTAL_PERSONAS_VOTARON  \
# MUNICIPIO
# Abasolo                           0                       0
# Agualeguas                        0                       0
# Allende                           0                       0
# Anahuac                           0                       0
# Apodaca                           0                       0
#
#             TOTAL_REP_PARTIDO_CI_VOTARON  TOTAL_VOTOS_SACADOS    PAN    PRI  \
# MUNICIPIO
# Abasolo                                0                    0    119    440
# Agualeguas                             0                    0   1216   1074
# Allende                                0                    0   4633   4764
# Anahuac                                0                    0   1582   3280
# Apodaca                                0                    0  50330  69818
#
#              PRD    PT  PVEM     MC  ...  CI_5  CI_6  CNR  Votos Anulados  \
# MUNICIPIO                            ...
# ...

# %%
NL_AYUN_2018.to_csv('final_NL_AYUN_2018.csv')

# %% [markdown]
# Alcaldes 2021

# %%
temp_2021 = pd.read_csv('NL_AYUN_2021.csv')

# %%
group = temp_2021.groupby('MUNICIPIO')

# %%
NL_AYUN_2021 = group.sum()

# %%
NL_AYUN_2021.head()
# Out:
#             ID_ESTADO  ID_MUNICIPIO  SECCION  ID_CASILLA  EXT_CONTIGUA  \
# MUNICIPIO
# Abasolo            76             4        6           4             0
# Agualeguas        190            20       66          10             0
# Allende           912           192     1283          81             0
# Anahuac           532           140     1268          32             0
# Apodaca         13965          4410   877485        1337           118
#
#             UBICACION_CASILLA  TIPO_ACTA  TOTAL_BOLETAS_SOBRANTES  \
# MUNICIPIO
# Abasolo                     8         16                      0.0
# Agualeguas                 19         40                      0.0
# Allende                    63        192                      0.0
# Anahuac                    38        112                      0.0
# Apodaca                   774       2940                  58540.0
#
#             TOTAL_PERSONAS_VOTARON  TOTAL_REP_PARTIDO_CI_VOTARON  ...  \
# ...

# %%
NL_AYUN_2021.drop(['ID_ESTADO','ID_MUNICIPIO','SECCION','ID_CASILLA','EXT_CONTIGUA','UBICACION_CASILLA','TIPO_ACTA','SHA','FECHA_HORA_ACOPIO','FECHA_HORA_VERIFICACION','ORIGEN','DIGITALIZACION'

], axis = 1, inplace= True)

# %%
NL_AYUN_2021.head()
# Out:
#             TOTAL_BOLETAS_SOBRANTES  TOTAL_PERSONAS_VOTARON  \
# MUNICIPIO
# Abasolo                         0.0                     0.0
# Agualeguas                      0.0                     0.0
# Allende                         0.0                     0.0
# Anahuac                         0.0                     0.0
# Apodaca                     58540.0                     0.0
#
#             TOTAL_REP_PARTIDO_CI_VOTARON  TOTAL_VOTOS_SACADOS    PAN     PRI  \
# MUNICIPIO
# Abasolo                              0.0                  0.0    544      31
# Agualeguas                           0.0                  0.0   1795     128
# Allende                              0.0                  0.0   3417    5947
# Anahuac                              0.0                  0.0    635    4775
# Apodaca                              0.0                  0.0  22136  141171
#
#              PRD  PVEM    PT     MC  ...  C_PT_MORENA  C_PT_PANAL  \
# MUNICIPIO                            ...
# ...

# %%
NL_AYUN_2021.to_csv('final_NL_AYUN_2021.csv')

# %% [markdown]
# Gobernador 2021

# %%
temp_NL_GOB_2021 = pd.read_csv('NL_GOB_2021.csv')

# %%
temp_NL_GOB_2021.head()
# Out:
#    CLAVE_CASILLA    CLAVE_ACTA  ID_ESTADO      ESTADO  ID_MUNICIPIO  \
# 0    190001B0100  190001B01002         19  NUEVO LEON             1
# 1    190001C0100  190001C01002         19  NUEVO LEON             1
# 2    190002B0100  190002B01002         19  NUEVO LEON             1
# 3    190002C0100  190002C01002         19  NUEVO LEON             1
# 4    190003B0100  190003B01002         19  NUEVO LEON             2
#
#     MUNICIPIO  ID_DISTRITO_LOCAL DISTRITO_LOCAL  SECCION  ID_CASILLA  ...  \
# 0     Abasolo                 20    DISTRITO 20        1           1  ...
# 1     Abasolo                 20    DISTRITO 20        1           1  ...
# 2     Abasolo                 20    DISTRITO 20        2           1  ...
# 3     Abasolo                 20    DISTRITO 20        2           1  ...
# 4  Agualeguas                 21    DISTRITO 21        3           1  ...
#
#   OBSERVACIONES  CONTABILIZADA  MECANISMOS_TRASLADO  SHA  FECHA_HORA_ACOPIO  \
# ...

# %%
group = temp_NL_GOB_2021.groupby('MUNICIPIO')

# %%
NL_GOB_2021 = group.sum()

# %%
NL_GOB_2021.head()
# Out:
#             ID_ESTADO  ID_MUNICIPIO  ID_DISTRITO_LOCAL  SECCION  ID_CASILLA  \
# MUNICIPIO
# Abasolo            76             4                 80        6           4
# Agualeguas        190            20                210       66          10
# Allende           912           192               1248     1283          81
# Anahuac           532           140                588     1268          32
# Apodaca         13965          4410               6589   877485        1337
#
#             EXT_CONTIGUA  UBICACION_CASILLA  TIPO_ACTA  \
# MUNICIPIO
# Abasolo                0                  8          8
# Agualeguas             0                 19         20
# Allende                0                 63         96
# Anahuac                0                 38         56
# Apodaca              118                774       1470
#
#             TOTAL_BOLETAS_SOBRANTES  TOTAL_PERSONAS_VOTARON  ...  \
# MUNICIPIO                                                    ...
# ...

# %%
NL_GOB_2021.drop(['ID_ESTADO','ID_MUNICIPIO','ID_DISTRITO_LOCAL','SECCION','ID_CASILLA','EXT_CONTIGUA','UBICACION_CASILLA','TIPO_ACTA','SHA','FECHA_HORA_ACOPIO','FECHA_HORA_VERIFICACION','ORIGEN','DIGITALIZACION'

], axis = 1, inplace= True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-60-4b2f948091b9> in <module>
# ----> 1 NL_GOB_2021.drop(['ID_ESTADO','ID_MUNICIPIO','SECCION','ID_CASILLA','EXT_CONTIGUA','UBICACION_CASILLA','TIPO_ACTA','SHA','FECHA_HORA_ACOPIO','FECHA_HORA_VERIFICACION','ORIGEN','DIGITALIZACION'
#       2
#       3 ], axis = 1, inplace= True)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4151         for axis, labels in axes.items():
#    4152             if labels is not None:
# ...

# %%
NL_GOB_2021.drop(['TOTAL_BOLETAS_SOBRANTES','TOTAL_PERSONAS_VOTARON','TOTAL_REP_PARTIDO_CI_VOTARON','TOTAL_VOTOS_SACADOS',

], axis = 1, inplace= True)

# %%
NL_GOB_2021.head()
# Out:
#             ID_DISTRITO_LOCAL    PAN    PRI  PRD  PVEM    PT     MC  MORENA  \
# MUNICIPIO
# Abasolo                    80    483    255   18   232    71    763     102
# Agualeguas                210   1515    340    4     9     4    778     161
# Allende                  1248   2340   4810   51   141   156   4106     860
# Anahuac                   588   1325   3979   29    99    77   1900    1046
# Apodaca                  6589  39757  58969  873  1756  2031  86520   22626
#
#             PANAL  PES  ...  C_PT_MORENA  C_PT_PANAL  C_MORENA_PANAL  \
# MUNICIPIO               ...
# Abasolo        20   20  ...            0           0               0
# Agualeguas      7    0  ...            0           0               0
# Allende       145   26  ...            2           2               4
# Anahuac        50   70  ...            1           0               2
# Apodaca       985  859  ...          147          13              40
#
# ...

# %%
NL_GOB_2021.to_csv('Final_NL_GOB_2021.csv')
